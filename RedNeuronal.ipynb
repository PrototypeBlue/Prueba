# %% [markdown]
# <a href="https://colab.research.google.com/github/PrototypeBlue/Prueba/blob/main/RedNeuronal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def normal_rule(x):
  y=2*x-1
  return y

print (normal_rule(-1))
print (normal_rule(0))
print (normal_rule(10))
# Out:
# -3
# -1
# 19

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
input_x=np.array([-1,0,1,2,3,4],dtype=float)
output_y=np.array([-3,-1,1,3,5,7],dtype=float)

# %%
for i,c in enumerate(input_x):
  print(c,output_y[i])
# Out:
# -1.0 -3.0
# 0.0 -1.0
# 1.0 1.0
# 2.0 3.0
# 3.0 5.0
# 4.0 7.0

# %%
model = tf.keras.Sequential(
    [keras.layers.Dense(units=1,input_shape=[1])]
)

# %%
model.compile(optimizer="sgd",loss="mean_squared_error")

# %%
history=model.fit(input_x,output_y,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 937us/step - loss: 1.8316e-05
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7939e-05
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7571e-05
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7210e-05
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6856e-05
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6510e-05
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6172e-05
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5839e-05
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5514e-05
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5195e-05
# Epoch 11/500
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4883e-05
# Epoch 12/500
# ...

# %%
print(history)

# %%
import matplotlib.pyplot as plt
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot(history.history["loss"])
plt.show()

# %%
print(model.predict([10,0]))
# Out:
# [[18.999926 ]
#  [-0.9999679]]

# %%
  print(model.get_weights())
# Out:
# [array([[1.9999893]], dtype=float32), array([-0.9999679], dtype=float32)]

# %%
model.save_weights("./checkpoints")
